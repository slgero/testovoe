# %%
import numpy as np
import pandas as pd
import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
sns.set_style("white")
# %matplotlib inline

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('test_ltv_ads.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 23 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   application_dm_id  500000 non-null  int64
#  1   install_dttm       500000 non-null  object
#  2   country_code       500000 non-null  int64
#  3   media_source       500000 non-null  int64
#  4   device_type        500000 non-null  int64
#  5   is_trial           500000 non-null  int64
#  6   app_version        500000 non-null  int64
#  7   campaign_id        500000 non-null  int64
#  8   os_name            500000 non-null  int64
#  9   city               500000 non-null  int64
#  10  adset_id           500000 non-null  int64
#  11  ad_id              500000 non-null  int64
#  12  publisher_site_id  500000 non-null  int64
#  13  device_locale      500000 non-null  int64
#  14  impressions0       500000 non-null  int64
#  15  impressions1       500000 non-null  int64
#  16  impressions2       500000 non-null  int64
#  17  impressions3       500000 non-null  int64
#  18  revenue0           500000 non-null  float64
#  19  revenue1           500000 non-null  float64
#  20  revenue2           500000 non-null  float64
#  21  revenue3           500000 non-null  float64
#  22  target             500000 non-null  float64
# dtypes: float64(5), int64(17), object(1)
# memory usage: 87.7+ MB

# %%
# revenue - доход за какой-то день
# impressions - количество просмотренной рекламы, после установки приложения

# %% [markdown]
# 1) http://www.gregreda.com/2015/08/23/cohort-analysis-with-python/ - сделать красивую визуализацию
#
# 2) разобраться по времени - что, когда, куда
#
# 3) попробовать модель, когда редкие значения будут заменены на NAN
#
#
#
# 4) Пайплан обработки: 1) обработать данные (хз, что тут можно, может заменить редко встречаемые на какую-то шляпу, потом нагенерировать дни недели и всё такое), попробовать завернуть это в папйлайн аля sklearn, 2) несколько моделей (какие зайдут лучше) либо 1 общую - неплохо, но возможно, непрофессионально, либо сделать несколько маленьких модлей и одну общю и методом голосования решать, чё кого (лол, так даже буде круче).

# %%
cols = []

for col in df.columns:
    if 'id' in col:
        cols.append(col)

# %%
df[cols]
# Out:
#         application_dm_id  campaign_id  adset_id  ad_id  publisher_site_id
# 0                      18            6         1      8                103
# 1                      18            1         1      1                  1
# 2                    9541          552       705    453                  1
# 3                      74            1         1      1                  1
# 4                    3753            1         1      1                  1
# ...                   ...          ...       ...    ...                ...
# 499995                 27            1         1      1                  1
# 499996                 74            1         1      1                  1
# 499997               5234          437       587    350                  1
# 499998              16792         1290         1      1                  1
# 499999                 27            1         1      1                  1
#
# [500000 rows x 5 columns]

# %%
df['media_source'].value_counts(normalize=True).head(10).mul(100).round(2).astype('str') + '%'
# Out:
# 1     45.33%
# 10    12.26%
# 8     10.34%
# 5     10.27%
# 4      7.06%
# 2      5.21%
# 11     3.33%
# 6      3.26%
# 27      1.7%
# 24     0.42%
# Name: media_source, dtype: object

# %%
df.sample(10)
# Out:
#         application_dm_id         install_dttm  country_code  media_source  \
# 35262                2774  2020-02-16 19:02:48            22             1
# 228233              16792  2020-04-20 17:42:53             2            10
# 340536                 39  2020-04-02 03:16:36            61            11
# 297743                 28  2020-02-09 10:17:59            77             4
# 62313                  18  2020-02-05 15:07:43            10             1
# 233964                 29  2020-03-17 08:05:05            26             5
# 162893               5234  2020-02-27 22:12:11             4             8
# 28098                  29  2020-03-13 19:58:09             4             5
# 233316               9541  2020-02-28 16:53:34            29            10
# 215947              14932  2020-04-20 06:41:39            21             8
#
#         device_type  is_trial  app_version  campaign_id  os_name   city  \
# 35262             1         0          188            1        1    200
# 228233            2         0           66         1295        2   9988
# 340536            1         0          286          833        2  79343
# 297743            1         0            8          788        2   1933
# 62313             1         0            4            1        1   3574
# 233964            1         0           58          129        1     53
# 162893            1         0            3          463        1  22966
# 28098             1         0           58          115        1   2291
# 233316            1         0          215          550        1   5699
# 215947            1         0            3          645        1  14412
#
#         adset_id  ad_id  publisher_site_id  device_locale  impressions0  \
# 35262          1      1                  1            103             2
# 228233      2073    565                  1              2             2
# 340536      1081      1                  1             58             0
# 297743         1     58              12958             70            18
# 62313          1      1                  1             52            26
# 233964         1      1                  1             22             5
# 162893         1    340               5330              4             8
# 28098          1      1                  1              4             8
# 233316       703    452                  1             73            33
# 215947         1    531               9889              9             1
#
#         impressions1  impressions2  impressions3  revenue0  revenue1  \
# 35262              0             0             0  0.002904  0.000000
# 228233             0             0             0  0.398440  0.000000
# 340536             0             0             0  0.000000  0.000000
# 297743             0             0             0  0.076401  0.000000
# 62313              8             0             0  0.017552  0.011936
# 233964             0             0             0  0.026424  0.000000
# 162893            10             0             0  0.041264  0.040530
# 28098              0             0             0  0.021254  0.000000
# 233316             0             0             0  0.074071  0.000000
# 215947             0             0             0  0.065550  0.000000
#
#         revenue2  revenue3    target
# 35262        0.0       0.0  0.002904
# 228233       0.0       0.0  0.398440
# 340536       0.0       0.0  0.000000
# 297743       0.0       0.0  0.076401
# 62313        0.0       0.0  0.029488
# 233964       0.0       0.0  0.026424
# 162893       0.0       0.0  0.106112
# 28098        0.0       0.0  0.021254
# 233316       0.0       0.0  0.074071
# 215947       0.0       0.0  0.065550

# %%
# Generate different time features:

df['install_dttm'] = pd.to_datetime(df['install_dttm'])
df['install_week'] = df['install_dttm'].apply(lambda x: x.week)
df['install_month'] = df['install_dttm'].apply(lambda x: x.month)
df['install_day'] = df['install_dttm'].apply(lambda x: x.day)
df['install_is_weekend'] = df['install_dttm'].apply(lambda x: x.weekday() > 4)

# %%
grouped = df.rename(columns={'install_month': 'cohort_group', 'install_week': 'cohort_period'}).groupby(['cohort_group', 'cohort_period'])
cohorts = grouped.agg({'target': 'sum'})

# %%
# Подумать, что у нас является периодом, а что нет
# Куда лучше всего запихнуть дни и недели

# %%
cohorts
# Out:
#                                   target
# cohort_group cohort_period
# 2            6               8017.872533
#              7               9503.995560
#              8               7290.244557
#              9               6876.782869
# 3            9               1533.559551
#              10              8555.223112
#              11              6063.816829
#              12              7131.380608
#              13              5948.055146
#              14              1076.719454
# 4            14              4114.714330
#              15              8935.806014
#              16             17924.942839
#              17              7967.284687

# %%
plt.figure(figsize=(12, 9))
plt.plot(
    df.groupby(f'install_week', as_index=False).agg({'target': 'sum'})['target'],
    ':', color='black', alpha=0.6, label='Total revenues'
)
plt.grid(axis='y', alpha=0.4)

# %%
def plot_distribution(df: pd.DataFrame, by: str) -> None:
    """
    The distribution of the number of installations by month
    or the week ordinal of the year.
    
    Parameters
    ----------
    df : pd.DataFrame
        Data for analysis.
    by : {'week', 'month'}
        Used to determine the groups for the groupby.
    """

    plt.figure(figsize=(12, 9))
    plt.plot(
        df.groupby(f'install_{by}', as_index=False).agg({'target': 'sum'})['target'],
        ':', color='black', alpha=0.6, label='Total revenues'
    )
    sns.countplot(df[f'install_{by}'])
    if by == 'month':
        plt.xticks(range(3), ['February', 'March', 'May'])
    plt.xlabel(f'Installation {by}', fontsize=16)
    plt.ylabel('Number of installations', fontsize=16)
    plt.legend(fontsize=14)
    plt.grid(axis='y', alpha=0.4)
    plt.title(f'The distribution of the number of installations by {by}', fontsize=18)
    plt.show()

# %%
plot_distribution(df, 'week')
plot_distribution(df, 'month')

# %%
df.head()
# Out:
#    application_dm_id        install_dttm  country_code  media_source  \
# 0                 18 2020-04-05 15:07:39            44             6
# 1                 18 2020-02-16 21:33:12            52             1
# 2               9541 2020-03-05 01:31:00            25            10
# 3                 74 2020-04-21 12:35:21            71             1
# 4               3753 2020-03-05 13:31:54             2             1
#
#    device_type  is_trial  app_version  campaign_id  os_name    city  adset_id  \
# 0            1         0           22            6        1     765         1
# 1            1         0            4            1        1  120175         1
# 2            1         0          215          552        1   29830       705
# 3            1         0          141            1        1     920         1
# 4            1         0            3            1        2   44647         1
#
#    ad_id  publisher_site_id  device_locale  impressions0  impressions1  \
# 0      8                103             11            25             0
# 1      1                  1             27            10            59
# 2    453                  1              2            23             0
# 3      1                  1             77             0             0
# 4      1                  1              2             5            12
#
#    impressions2  impressions3  revenue0  revenue1  revenue2  revenue3  \
# 0             0             0  0.020042  0.000000  0.000000  0.000000
# 1            24            20  0.020169  0.111984  0.032424  0.098230
# 2             0             3  5.190124  0.000000  0.000000  0.604506
# 3             0             0  0.000000  0.000000  0.000000  0.000000
# 4             5             5  0.003989  0.238139  0.063731  0.068518
#
#      target  install_week  install_month  install_is_weekend
# 0  0.020042            14              4                True
# 1  0.313710             7              2                True
# 2  5.794630            10              3               False
# 3  0.000000            17              4               False
# 4  0.571443            10              3               False

# %%
df['install_is_weekend']

# %%
df['target'].describe()
# Out:
# count    500000.000000
# mean          0.201881
# std           1.212041
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.057732
# max         192.515075
# Name: target, dtype: float64

# %%
df[df['country_code'] == 3]['city'].value_counts(normalize=True).tail(10).mul(100).round(2).astype('str') + '%'
# Out:
# 66952    0.0%
# 48479    0.0%
# 44253    0.0%
# 54482    0.0%
# 5322     0.0%
# 73776    0.0%
# 43105    0.0%
# 54354    0.0%
# 73872    0.0%
# 56852    0.0%
# Name: city, dtype: object

# %%
df['country_code'].value_counts(normalize=True).head(10).mul(100).round(2).astype('str') + '%'
# Out:
# 3      12.09%
# 4       9.99%
# 2       9.58%
# 21      5.72%
# 139     4.05%
# 31       3.1%
# 45      2.97%
# 25      2.57%
# 27      2.51%
# 52      2.48%
# Name: country_code, dtype: object

# %%
df['os_name'].value_counts(normalize=True).head(10).mul(100).round(2).astype('str') + '%'
# Out:
# 1    80.29%
# 2    19.71%
# Name: os_name, dtype: object

# %%
# Remove duplicate items 
df = df[~df.duplicated()]
df.shape
# Out:
# (500000, 23)

# %%
df.index = pd.to_datetime(df['install_dttm'])

# %%
print(df.index.min())
print(df.index.max())
# Out:
# 2020-02-03 23:38:06
# 2020-04-24 00:22:46

# %%
df.groupby(pd.Grouper(freq='M')).agg({'application_dm_id': 'count'}).plot(kind='bar', rot=45);

# %%
df['install_dttm'].apply(lambda x: x.month)
# Out:
# 0    4
# 1    2
# 2    3
# 3    4
# 4    3
# Name: install_dttm, dtype: int64

# %%
df['install_dttm'].groupby('month')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-dddcc65a242d> in <module>
# ----> 1 df['install_dttm'].groupby('month')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    1685             group_keys=group_keys,
#    1686             squeeze=squeeze,
# -> 1687             observed=observed,
#    1688         )
#    1689
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     408                 sort=sort,
#     409                 observed=observed,
# --> 410                 mutated=self.mutated,
#     411             )
#     412
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     598                 in_axis, name, level, gpr = False, None, gpr, None
#     599             else:
# --> 600                 raise KeyError(gpr)
#     601         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     602             # Add key to exclusions
#
# KeyError: 'month'

# %%
df.head()
# Out:
#    application_dm_id        install_dttm  country_code  media_source  \
# 0                 18 2020-04-05 15:07:39            44             6
# 1                 18 2020-02-16 21:33:12            52             1
# 2               9541 2020-03-05 01:31:00            25            10
# 3                 74 2020-04-21 12:35:21            71             1
# 4               3753 2020-03-05 13:31:54             2             1
#
#    device_type  is_trial  app_version  campaign_id  os_name    city  ...  \
# 0            1         0           22            6        1     765  ...
# 1            1         0            4            1        1  120175  ...
# 2            1         0          215          552        1   29830  ...
# 3            1         0          141            1        1     920  ...
# 4            1         0            3            1        2   44647  ...
#
#    device_locale  impressions0  impressions1  impressions2  impressions3  \
# 0             11            25             0             0             0
# 1             27            10            59            24            20
# 2              2            23             0             0             3
# 3             77             0             0             0             0
# 4              2             5            12             5             5
#
#    revenue0  revenue1  revenue2  revenue3    target
# 0  0.020042  0.000000  0.000000  0.000000  0.020042
# 1  0.020169  0.111984  0.032424  0.098230  0.313710
# 2  5.190124  0.000000  0.000000  0.604506  5.794630
# 3  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.003989  0.238139  0.063731  0.068518  0.571443
#
# [5 rows x 23 columns]

# %%
sns.countplot(df['install_dttm'].head(20))

# %%
df['install_dttm'].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-4ae0eb3d550a> in <module>
# ----> 1 df['install_dttm'].plot(kind='bar')
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1403                     label=label,
#    1404                     log=self.log,
# -> 1405                     **kwds,
#    1406                 )
#    1407             self._add_legend_handle(rect, label, index=i)
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1328     @classmethod
#    1329     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1330         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1331
#    1332     @property
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2435             elif orientation == 'horizontal':
#    2436                 r.sticky_edges.x.append(l)
# -> 2437             self.add_patch(r)
#    2438             patches.append(r)
#    2439
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    1968         self._set_artist_props(p)
#    1969         if p.get_clip_path() is None:
# -> 1970             p.set_clip_path(self.patch)
#    1971         self._update_patch_limits(p)
#    1972         self.patches.append(p)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in set_clip_path(self, path, transform)
#     730             if isinstance(path, Rectangle):
#     731                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 732                                                path.get_transform())
#     733                 self._clippath = None
#     734                 success = True
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/patches.py in get_transform(self)
#     212         to the :class:`Patch`.
#     213         """
# --> 214         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     215
#     216     def get_data_transform(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/patches.py in get_patch_transform(self)
#     756
#     757     def get_patch_transform(self):
# --> 758         self._update_patch_transform()
#     759         return self._rect_transform
#     760
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/patches.py in _update_patch_transform(self)
#     735         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
#     736         rot_trans = transforms.Affine2D()
# --> 737         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     738         self._rect_transform = transforms.BboxTransformTo(bbox)
#     739         self._rect_transform += rot_trans
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in rotate_deg_around(self, x, y, degrees)
#    1958         # Cast to float to avoid wraparound issues with uint8's
#    1959         x, y = float(x), float(y)
# -> 1960         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    1961
#    1962     def translate(self, tx, ty):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in rotate_deg(self, degrees)
#    1936         and :meth:`scale`.
#    1937         """
# -> 1938         return self.rotate(np.deg2rad(degrees))
#    1939
#    1940     def rotate_around(self, x, y, theta):
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f11ac4e7950> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2061                         orientation=orientation,
#    2062                         dryrun=True,
# -> 2063                         **kwargs)
#    2064                     renderer = self.figure._cachedRenderer
#    2065                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/patches.py in draw(self, renderer)
#     578                       # do not draw the hatches if the facecolor is fully
#     579                       # transparent, but do if it is None.
# --> 580                       self._facecolor if self._facecolor[3] else None)
#     581
#     582     def get_path(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     144         else:
#     145             try:
# --> 146                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     147             except OverflowError:
#     148                 raise OverflowError("Exceeded cell block limit (set "
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in __array__(self, *args, **kwargs)
#     279
#     280     def __array__(self, *args, **kwargs):
# --> 281         return self.get_points()
#     282
#     283     def is_unit(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py in get_points(self)
#    1041                 xs = xs[::-1]
#    1042
# -> 1043             ys = min(points[:, 1]), max(points[:, 1])
#    1044             if p[0, 1] > p[1, 1]:
#    1045                 ys = ys[::-1]
#
# KeyboardInterrupt:
